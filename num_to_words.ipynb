# %% [markdown]
# ## **Usage of num_to_words() function**

# %% [markdown]
# - **With integer**

# %%
from variety import num_to_words
num_to_words(503)
# Out:
# 'five hundred and three'

# %% [markdown]
# - **With decimal**
# *(will throw error)*

# %%
num_to_words(55.6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 num_to_words(55.6)
#
# File c:\Users\Dell\Documents\Python-Functions-Playground\variety.py:286, in num_to_words(a)
#     280     # 1 - 999,999,999,999,999,999,999,999,999,999 FUNCTION ENDS HERE
#     281
#     282
#     283 # 1 - 999,999,999,999,999,999,999,999,999,999,999 FUNCTION STARTS HERE
#     284 # formating the digits with comma seperator
#     285 if not isinstance(a,(int)):
# --> 286     raise ValueError (f"{a} is not allowed")
#     287 d = f"{a:,}"
#     288 # condition for octillion
#
# ValueError: 55.6 is not allowed

# %% [markdown]
# - **With negative number**
# *(will throw error)*

# %%
num_to_words(-4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 num_to_words(-4)
#
# File c:\Users\Dell\Documents\Python-Functions-Playground\variety.py:302, in num_to_words(a)
#     300         return f"{one_octillion(b)} nonillion"
#     301 else:
# --> 302     return one_octillion(a)
#
# File c:\Users\Dell\Documents\Python-Functions-Playground\variety.py:23, in num_to_words.<locals>.one_octillion(a)
#      21 def one_octillion(a):
#      22     if a < 1:
# ---> 23         raise ValueError (f"{a} is not allowed")
#      24     def one_septillion(a):
#      25         def one_sextillion(a):
#
# ValueError: -4 is not allowed

# %% [markdown]
# - **With string**
# *(will throw error)*

# %%
num_to_words("gd")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 num_to_words("gd")
#
# File c:\Users\Dell\Documents\Python-Functions-Playground\variety.py:286, in num_to_words(a)
#     280     # 1 - 999,999,999,999,999,999,999,999,999,999 FUNCTION ENDS HERE
#     281
#     282
#     283 # 1 - 999,999,999,999,999,999,999,999,999,999,999 FUNCTION STARTS HERE
#     284 # formating the digits with comma seperator
#     285 if not isinstance(a,(int)):
# --> 286     raise ValueError (f"{a} is not allowed")
#     287 d = f"{a:,}"
#     288 # condition for octillion
#
# ValueError: gd is not allowed
