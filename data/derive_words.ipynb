# %% [markdown]
# ## **Usage of derive_words() funtion**
# - import the function from variety module
# - use this word **`amte`**

# %%
from variety import derive_words
derive_words("amte",4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from variety import derive_words
# ----> 2 derive_words("amte",4)
#
# File c:\Users\Dell\Documents\Python-Functions-Playground\notebooks\variety.py:369, in derive_words(letters, min_letters, max_letters)
#     367 from itertools import permutations as pm, combinations as cb
#     368 # Accessing English dictionary words text files
# --> 369 with open(r"data\engmix.txt") as file:
#     370     content = file.readlines()
#     371 # removing the newlines ending each words
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\engmix.txt'

# %% [markdown]
# - ***Let's see how the function can solve this puzzle***
#
#
# ![Screenshot_20251103-120631.png](attachment:Screenshot_20251103-120631.png)

# %%
derive_words("scots",4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 derive_words("scots",4)
#
# NameError: name 'derive_words' is not defined
